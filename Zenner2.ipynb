# %%
# !pip install flask flask-cors pyngrok pandas matplotlib
# !pkill ngrok

import time
import random
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
from flask import Flask, jsonify, send_from_directory
from flask_cors import CORS
from threading import Thread
from pyngrok import ngrok

# Initialize Flask
app = Flask(__name__)


CORS(app, resources={
    r"/*": {
        "origins": [
            "http://localhost:3000",
            "https://*.ngrok-free.app",

        ],
        "methods": ["GET", "POST", "OPTIONS"],
        "allow_headers": [
            "Content-Type",
            "User-Agent",
            "ngrok-skip-browser-warning",
            "Cache-Control"
        ],
        "supports_credentials": True
    }
})


#CORS(app, resources={r"/*": {"origins": "*"}})

# Ngrok Configuration
NGROK_AUTHTOKEN = "2sDUAt3lglQCWmGXxgFCcGTCeSa_3MN13k8g6y79iT7oc44MR"  # Replace with your token
ngrok.set_auth_token(NGROK_AUTHTOKEN)
# public_url = ngrok.connect(5001).public_url
# print(f"Ngrok URL: {public_url}")

# public_url = ngrok.connect(addr=5001, bind_tls=True).public_url

public_url = ngrok.connect(addr=5001, bind_tls=True).public_url.replace('http://', 'https://')
print(f"Ngrok URL: {public_url}")



def generate_smart_meter_data():
    return {
        "meter_id": "WaterMeter_001",
        "timestamp": time.strftime("%Y-%m-%d %H:%M:%S"),
        "water_usage_liters": round(random.uniform(50, 200), 2),
        "battery_status": round(random.uniform(3.0, 4.2), 2),
    }

def encode_packet(data):
    data["checksum"] = sum(ord(c) for c in json.dumps(data)) % 256
    return data

def send_data_via_lora(packet):
    print(f"Simulating LoRa transmission: {packet}")

def receive_data_via_lora():
    data = generate_smart_meter_data()
    encoded_packet = encode_packet(data)
    print(f"Simulated received packet: {encoded_packet}")
    return encoded_packet

def decode_packet(packet):
    received_checksum = packet.pop("checksum", None)
    calculated_checksum = sum(ord(c) for c in json.dumps(packet)) % 256
    if received_checksum == calculated_checksum:
        print("Packet integrity verified.")
        return packet
    else:
        print("Packet integrity check failed.")
        return None

def log_received_data(data):
    try:
        with open('meter_data.log.txt', 'a') as file:
            file.write(json.dumps(data) + '\n')
        print(f"Data logged: {data}")
    except Exception as e:
        print(f"Error logging data: {e}")

def visualize_data():
    try:
        if not os.path.exists('meter_data.log.txt'):
            print("Log file not found.")
            return

        data = pd.read_json('meter_data.log.txt', lines=True)
        data['timestamp'] = pd.to_datetime(data['timestamp'], errors='coerce', format='%Y-%m-%d %H:%M')
        data = data.dropna(subset=['timestamp'])
        data = data.sort_values(by='timestamp')

        plt.figure()
        plt.plot(data['timestamp'], data['water_usage_liters'], label='Water Usage (Liters) Over Time')
        plt.xlabel('Timestamp')
        plt.ylabel('Water Usage (Liters)')
        plt.title('Water Usage Over Time')
        plt.legend()
        plt.grid()

        image_path = '/content/drive/MyDrive/water_usage_graph_2.png'
        plt.savefig(image_path)
        plt.close()

        print("Visualization complete. Image saved as water_usage_graph_2.png.")
    except Exception as e:
        print(f"Error visualizing data: {e}")

# Flask Routes
@app.route('/')
def home():
    return jsonify({"message": "Smart Meter API"})

@app.route('/get-ngrok-url')
def get_ngrok_url():
    return jsonify({
        "ngrok_url": public_url.split('?')[0]  # Return URL without query params
    })


@app.route('/log-data', methods=['POST'])
def log_data():
    try:
        received_packet = receive_data_via_lora()
        decoded_data = decode_packet(received_packet)
        if decoded_data:
            log_received_data(decoded_data)
        return jsonify({"status": "success", "message": "Data received and logged."}), 200
    except Exception as e:
        return jsonify({"status": "error", "message": str(e)}), 500

@app.route('/visualize')
def visualize():
    try:
        visualize_data()
        return jsonify({"status": "success", "message": "Visualization complete."}), 200
    except Exception as e:
        return jsonify({"status": "error", "message": str(e)}), 500


image_path = '/content/drive/MyDrive/water_usage_graph_2.png'  # Save path
@app.route('/images/<filename>')
def get_image(filename):
    try:
        return send_from_directory('/content/drive/MyDrive', filename)
    except Exception as e:
        return jsonify({"error": str(e)}), 500


# Main Execution
if __name__ == '__main__':
    from google.colab import drive
    drive.mount('/content/drive')

    def run_flask():
        app.run(host="0.0.0.0", port=5001)

    flask_thread = Thread(target=run_flask)
    flask_thread.start()

    try:
        print("Starting LoRa Simulation...")
        for _ in range(40):
            received_packet = receive_data_via_lora()
            decoded_data = decode_packet(received_packet)
            if decoded_data:
                log_received_data(decoded_data)
            time.sleep(2)

        print("\nVisualizing logged data...")
        visualize_data()
    except KeyboardInterrupt:
        print("Stopping the LoRa simulation.")
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (3.1.0)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.11/dist-packages (5.0.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.11/dist-packages (7.2.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Ngrok URL: https://e883-34-139-237-33.ngrok-free.app
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting LoRa Simulation...
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:14', 'water_usage_liters': 129.76, 'battery_status': 3.16, 'checksum': 22}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:14', 'water_usage_liters': 129.76, 'battery_status': 3.16}
#  * Serving Flask app '__main__'
#  * Debug mode: off
# Address already in use
# Port 5001 is in use by another program. Either identify and stop that program, or start the server with a different port.
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:16', 'water_usage_liters': 115.34, 'battery_status': 3.43, 'checksum': 13}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:16', 'water_usage_liters': 115.34, 'battery_status': 3.43}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:18', 'water_usage_liters': 60.81, 'battery_status': 3.02, 'checksum': 219}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:18', 'water_usage_liters': 60.81, 'battery_status': 3.02}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:20', 'water_usage_liters': 148.98, 'battery_status': 4.16, 'checksum': 25}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:20', 'water_usage_liters': 148.98, 'battery_status': 4.16}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:22', 'water_usage_liters': 153.28, 'battery_status': 3.78, 'checksum': 23}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:22', 'water_usage_liters': 153.28, 'battery_status': 3.78}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:24', 'water_usage_liters': 165.8, 'battery_status': 3.32, 'checksum': 224}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:24', 'water_usage_liters': 165.8, 'battery_status': 3.32}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:26', 'water_usage_liters': 76.72, 'battery_status': 3.04, 'checksum': 227}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:26', 'water_usage_liters': 76.72, 'battery_status': 3.04}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:28', 'water_usage_liters': 95.08, 'battery_status': 3.73, 'checksum': 235}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:28', 'water_usage_liters': 95.08, 'battery_status': 3.73}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:30', 'water_usage_liters': 162.67, 'battery_status': 3.34, 'checksum': 17}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:30', 'water_usage_liters': 162.67, 'battery_status': 3.34}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:32', 'water_usage_liters': 97.06, 'battery_status': 3.97, 'checksum': 236}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:32', 'water_usage_liters': 97.06, 'battery_status': 3.97}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:34', 'water_usage_liters': 132.04, 'battery_status': 3.8, 'checksum': 218}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:34', 'water_usage_liters': 132.04, 'battery_status': 3.8}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:36', 'water_usage_liters': 129.27, 'battery_status': 3.91, 'checksum': 25}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:36', 'water_usage_liters': 129.27, 'battery_status': 3.91}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:38', 'water_usage_liters': 116.67, 'battery_status': 4.13, 'checksum': 22}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:38', 'water_usage_liters': 116.67, 'battery_status': 4.13}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:40', 'water_usage_liters': 141.9, 'battery_status': 4.04, 'checksum': 217}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:40', 'water_usage_liters': 141.9, 'battery_status': 4.04}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:42', 'water_usage_liters': 142.3, 'battery_status': 4.09, 'checksum': 219}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:42', 'water_usage_liters': 142.3, 'battery_status': 4.09}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:44', 'water_usage_liters': 100.85, 'battery_status': 3.63, 'checksum': 16}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:44', 'water_usage_liters': 100.85, 'battery_status': 3.63}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:46', 'water_usage_liters': 123.76, 'battery_status': 3.1, 'checksum': 223}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:46', 'water_usage_liters': 123.76, 'battery_status': 3.1}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:48', 'water_usage_liters': 143.66, 'battery_status': 3.78, 'checksum': 32}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:48', 'water_usage_liters': 143.66, 'battery_status': 3.78}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:50', 'water_usage_liters': 133.56, 'battery_status': 3.96, 'checksum': 23}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:50', 'water_usage_liters': 133.56, 'battery_status': 3.96}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:52', 'water_usage_liters': 156.24, 'battery_status': 3.21, 'checksum': 13}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:52', 'water_usage_liters': 156.24, 'battery_status': 3.21}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:54', 'water_usage_liters': 122.13, 'battery_status': 3.82, 'checksum': 13}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:54', 'water_usage_liters': 122.13, 'battery_status': 3.82}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:56', 'water_usage_liters': 52.85, 'battery_status': 4.04, 'checksum': 229}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:56', 'water_usage_liters': 52.85, 'battery_status': 4.04}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:58', 'water_usage_liters': 157.67, 'battery_status': 3.31, 'checksum': 28}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:42:58', 'water_usage_liters': 157.67, 'battery_status': 3.31}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:00', 'water_usage_liters': 101.96, 'battery_status': 3.76, 'checksum': 16}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:00', 'water_usage_liters': 101.96, 'battery_status': 3.76}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:02', 'water_usage_liters': 89.54, 'battery_status': 3.33, 'checksum': 228}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:02', 'water_usage_liters': 89.54, 'battery_status': 3.33}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:04', 'water_usage_liters': 190.51, 'battery_status': 3.17, 'checksum': 14}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:04', 'water_usage_liters': 190.51, 'battery_status': 3.17}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:06', 'water_usage_liters': 181.86, 'battery_status': 4.02, 'checksum': 19}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:06', 'water_usage_liters': 181.86, 'battery_status': 4.02}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:08', 'water_usage_liters': 50.79, 'battery_status': 4.08, 'checksum': 232}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:08', 'water_usage_liters': 50.79, 'battery_status': 4.08}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:10', 'water_usage_liters': 189.02, 'battery_status': 3.53, 'checksum': 15}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:10', 'water_usage_liters': 189.02, 'battery_status': 3.53}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:12', 'water_usage_liters': 51.03, 'battery_status': 3.84, 'checksum': 218}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:12', 'water_usage_liters': 51.03, 'battery_status': 3.84}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:14', 'water_usage_liters': 175.96, 'battery_status': 3.36, 'checksum': 28}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:14', 'water_usage_liters': 175.96, 'battery_status': 3.36}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:16', 'water_usage_liters': 55.18, 'battery_status': 3.33, 'checksum': 226}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:16', 'water_usage_liters': 55.18, 'battery_status': 3.33}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:18', 'water_usage_liters': 190.4, 'battery_status': 3.2, 'checksum': 171}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:18', 'water_usage_liters': 190.4, 'battery_status': 3.2}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:20', 'water_usage_liters': 107.06, 'battery_status': 4.14, 'checksum': 8}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:20', 'water_usage_liters': 107.06, 'battery_status': 4.14}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:22', 'water_usage_liters': 197.11, 'battery_status': 3.28, 'checksum': 19}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:22', 'water_usage_liters': 197.11, 'battery_status': 3.28}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:24', 'water_usage_liters': 146.7, 'battery_status': 3.24, 'checksum': 224}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:24', 'water_usage_liters': 146.7, 'battery_status': 3.24}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:26', 'water_usage_liters': 67.39, 'battery_status': 3.43, 'checksum': 234}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:26', 'water_usage_liters': 67.39, 'battery_status': 3.43}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:28', 'water_usage_liters': 167.27, 'battery_status': 3.64, 'checksum': 29}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:28', 'water_usage_liters': 167.27, 'battery_status': 3.64}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:30', 'water_usage_liters': 139.21, 'battery_status': 3.91, 'checksum': 15}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:30', 'water_usage_liters': 139.21, 'battery_status': 3.91}
# Simulated received packet: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:32', 'water_usage_liters': 131.67, 'battery_status': 3.08, 'checksum': 17}
# Packet integrity verified.
# Data logged: {'meter_id': 'WaterMeter_001', 'timestamp': '2025-01-30 10:43:32', 'water_usage_liters': 131.67, 'battery_status': 3.08}
#
# Visualizing logged data...
# Visualization complete. Image saved as water_usage_graph_2.png.
